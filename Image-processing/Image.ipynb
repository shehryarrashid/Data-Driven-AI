# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from os import walk
import os
import glob
import tensorflow as tf

for i in range(1,9):
    folder_path = f'./u2271070_images/Stage{i}_h'
    output_folder = f'Resized_Images/Resized_Stage{i}'
    os.makedirs(output_folder, exist_ok=True)
    j = 1
# Loop through each image in the folder
    for filename in os.listdir(folder_path):
        if filename.endswith(('.jpg', '.jpeg', '.png')): 
        # Read the image
            image_path = os.path.join(folder_path, filename)
            image = cv2.imread(image_path)

            # Resize the image to 150x150
            resized_image = cv2.resize(image, (150, 150))

            # Save the resized image in the output folder
            output_path = os.path.join(output_folder, f'Stage_{i}_u2271070_({j}).jpg')
            cv2.imwrite(output_path, resized_image)

            print(f"Resized and saved {filename}")
            j += 1
# Out:
# Resized and saved IMG_1646.jpg
# Resized and saved IMG_1645.jpg
# Resized and saved IMG_1644.jpg
# Resized and saved IMG_1640.jpg
# Resized and saved IMG_1641.jpg
# Resized and saved IMG_1643.jpg
# Resized and saved IMG_1637.jpg
# Resized and saved IMG_1636.jpg
# Resized and saved IMG_1638.jpg
# Resized and saved IMG_1639.jpg
# Resized and saved IMG_1654.jpg
# Resized and saved IMG_1655.jpg
# Resized and saved IMG_1656.jpg
# Resized and saved IMG_1673.jpg
# Resized and saved IMG_1672.jpg
# Resized and saved IMG_1670.jpg
# Resized and saved IMG_1671.jpg
# Resized and saved IMG_1661.jpg
# Resized and saved IMG_1674.jpg
# Resized and saved IMG_1660.jpg
# Resized and saved IMG_1685.jpg
# Resized and saved IMG_1684.jpg
# Resized and saved IMG_1686.jpg
# Resized and saved IMG_1683.jpg
# Resized and saved IMG_1697.jpg
# Resized and saved IMG_1696.jpg
# Resized and saved IMG_1695.jpg
# Resized and saved IMG_1675.jpg
# Resized and saved IMG_1676.jpg
# Resized and saved IMG_1677.jpg
# Resized and saved IMG_1720.jpg
# Resized and saved IMG_1708.jpg
# Resized and saved IMG_1709.jpg
# Resized and saved IMG_1721.jpg
# Resized and saved IMG_1722.jpg
# Resized and saved IMG_1698.jpg
# Resized and saved IMG_1707.jpg
# Resized and saved IMG_1699.jpg
# Resized and saved IMG_1710.jpg
# Resized and saved IMG_1700.jpg
# Resized and saved IMG_1726.jpg
# Resized and saved IMG_1732.jpg
# Resized and saved IMG_1733.jpg
# Resized and saved IMG_1725.jpg
# Resized and saved IMG_1724.jpg
# Resized and saved IMG_1734.jpg
# Resized and saved IMG_1735.jpg
# Resized and saved IMG_1745.jpg
# Resized and saved IMG_1744.jpg
# Resized and saved IMG_1743.jpg
# Resized and saved IMG_1752.jpg
# Resized and saved IMG_1746.jpg
# Resized and saved IMG_1747.jpg
# Resized and saved IMG_1753.jpg
# Resized and saved IMG_1756.jpg
# Resized and saved IMG_1754.jpg
# Resized and saved IMG_1770.jpg
# Resized and saved IMG_1771.jpg
# Resized and saved IMG_1772.jpg
# Resized and saved IMG_1748.jpg
# Resized and saved IMG_1792.jpg
# Resized and saved IMG_1793.jpg
# Resized and saved IMG_1787.jpg
# Resized and saved IMG_1797.jpg
# Resized and saved IMG_1798.jpg
# Resized and saved IMG_1773.jpg
# Resized and saved IMG_1799.jpg
# Resized and saved IMG_1789.jpg
# Resized and saved IMG_1788.jpg
# Resized and saved IMG_1774.jpg
# Resized and saved IMG_1803.jpg
# Resized and saved IMG_1801.jpg
# Resized and saved IMG_1800.jpg
# Resized and saved IMG_1804.jpg
# Resized and saved IMG_1810.jpg
# Resized and saved IMG_1812.jpg
# Resized and saved IMG_1823.jpg
# Resized and saved IMG_1822.jpg
# Resized and saved IMG_1825.jpg
# Resized and saved IMG_1824.jpg
